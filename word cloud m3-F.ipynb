# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('0828_data.csv', header=None)
df.head()
# Out:
#          0          1     2
# 0  하남 스타필드       워터파크  워터파크
# 1  하남 스타필드  경기도 실내수영장  워터파크
# 2  하남 스타필드        아쿠아  워터파크
# 3  하남 스타필드         맛집   식음료
# 4  하남 스타필드   아쿠아필드 시간  워터파크

# %%
df.columns = ['shoppingmall', 'search_word', 'keyword']
df.head()
# Out:
#   shoppingmall search_word keyword
# 0      하남 스타필드        워터파크    워터파크
# 1      하남 스타필드   경기도 실내수영장    워터파크
# 2      하남 스타필드         아쿠아    워터파크
# 3      하남 스타필드          맛집     식음료
# 4      하남 스타필드    아쿠아필드 시간    워터파크

# %%
df3 = df['keyword']
df3.head()
# Out:
# 0    워터파크
# 1    워터파크
# 2    워터파크
# 3     식음료
# 4    워터파크
# Name: keyword, dtype: object

# %%
shoppingmall = ["하남 스타필드", "코엑스 스타필드", "강변 테크노마트", "아이파크몰", "가든파이브", "타임스퀘어", "디큐브시티", "롯데몰 김포",
                 "롯데몰 은평", "ifc몰"]

var = []
for i in shoppingmall:
    word = df3[df["shoppingmall"] == i]
    var.append(word)
    var
    print(i)
    print(word)
    print()
# Out:
# 하남 스타필드
# 0       워터파크
# 1       워터파크
# 2       워터파크
# 3        식음료
# 4       워터파크
# 5       워터파크
# 6       워터파크
# 7       워터파크
# 8       워터파크
# 9       워터파크
# 10      워터파크
# 11        영화
# 12       찜질방
# 13    스포츠몬스터
# 14      키즈카페
# 15       백화점
# 16      워터파크
# 17      워터파크
# 18        주차
# 19      레스토랑
# 20      워터파크
# 21       백화점
# 22       찜질방
# 23       식음료
# 24        영화
# 25        네일
# 26    베이비엔젤스
# 27       가는길
# 28    스포츠몬스터
# 29        스파
# 30        스파
# 31        뷰티
# 32       1주년
# 33        한샘
# 34       식음료
# 35        패션
# 36       나들이
# 37       데이트
# 38        패션
# 39       식음료
# 40        근처
# 41       백화점
# 42       식음료
# 43        쇼핑
# 44        꽃집
# 45        구경
# 46      토이킹덤
# Name: 2, dtype: object
#
# 코엑스 스타필드
# 47        놀거리
# 48        식음료
# 49      아쿠아리움
# 50         쇼핑
# 51        킨텍스
# 52        코믹콘
# 53      대학박람회
# 54         서점
# 55       지하철역
# 56         부산
# 57        식음료
# 58         주차
# 59         주차
# 60        도서관
# 61        식음료
# ...

# %%
# a=[]
# for i in range(5):    
#     a.append(i)
# a

# %%
# shoppingmall = ["하남 스타필드", "코엑스 스타필드", "강변 테크노마트", "아이파크몰", "가든파이브", "타임스퀘어", "디큐브시티", "롯데몰 김포",
#                  "롯데몰 은평", "ifc몰"]
# i = shoppingmall[0]

# for i in shoppingmall:
#     i = shoppingmall[+1]
#     word = df3.loc[df[0] == i]
    
# print(word)

# df3[df['shoppingmall'].isin(['하남 스타필드','코엑스 스타필드'])]

# %%
# var[0]

# %%
# hanam = df3.loc[df[0] == '하남 스타필드']
# coex = df3.loc[df[0] == '코엑스 스타필드']
# techno = df3.loc[df[0] == '강변 테크노마트']
# ipark = df3.loc[df[0] == '아이파크몰']
# gardenfive = df3.loc[df[0] == '가든파이브']
# timessquare = df3.loc[df[0] == '타임스퀘어']
# dcube = df3.loc[df[0] == '디큐브시티']
# gimpo = df3.loc[df[0] == '롯데몰 김포']
# eunpyeong = df3.loc[df[0] == '롯데몰 은평']
# ifc = df3.loc[df[0] == 'ifc몰']

# %%
# df3.loc[:50]

# %%
# !pip install -q 'wordcloud[all]'
# Out:
#   wordcloud 1.5.0 does not provide the extra 'all'

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

def displayWordCloud(data = None, backgroundcolor = 'white', width=800, height=600 ):
    wordcloud = WordCloud(
                        font_path = fontpath,
                        stopwords = STOPWORDS, # 한국어는 해당이 없습니다. 한국어를 적용해 주려면 별도 처리가 필요합니다.
                        background_color = backgroundcolor, 
                         width = width, height = height).generate(data)
    plt.figure(figsize = (15 , 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
# Out:
# apt: invalid flag: -qq
# Usage: apt <apt and javac options> <source files>
# where apt options include:
#   -classpath <path>          Specify where to find user class files and annotation processor factories
#   -cp <path>                 Specify where to find user class files and annotation processor factories
#   -d <path>                  Specify where to place processor and javac generated class files
#   -s <path>                  Specify where to place processor generated source files
#   -source <release>          Provide source compatibility with specified release
#   -version                   Version information
#   -help                      Print a synopsis of standard options; use javac -help for more options
#   -X                         Print a synopsis of nonstandard options
#   -J<flag>                   Pass <flag> directly to the runtime system
#   -A[key[=value]]            Options to pass to annotation processors
# ...

# %%
displayWordCloud(' '.join(df3))  # 전체

# %%
displayWordCloud(' '.join(var[0]))  # 하남 스타필드

# %%
displayWordCloud(' '.join(var[1]))  # 코엑스 스타필드

# %%
displayWordCloud(' '.join(var[2]))  # 강변 테크노마트

# %%
displayWordCloud(' '.join(var[3]))  # 아이파크몰

# %%
displayWordCloud(' '.join(var[4]))  # 가든파이브

# %%
displayWordCloud(' '.join(var[5]))  # 타임스퀘어

# %%
displayWordCloud(' '.join(var[6]))  # 디큐브시티

# %%
displayWordCloud(' '.join(var[7]))  # 롯데몰 김포

# %%
displayWordCloud(' '.join(var[8]))  # 롯데몰 은평

# %%
displayWordCloud(' '.join(var[9]))  # ifc몰
