# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('0828_data.csv', header=None)
df.head(50)
# Out:
#            0           1       2
# 0    하남 스타필드        워터파크    워터파크
# 1    하남 스타필드   경기도 실내수영장    워터파크
# 2    하남 스타필드         아쿠아    워터파크
# 3    하남 스타필드          맛집     식음료
# 4    하남 스타필드    아쿠아필드 시간    워터파크
# 5    하남 스타필드         수영장    워터파크
# 6    하남 스타필드    아쿠아필드 수건    워터파크
# 7    하남 스타필드    아쿠아필드 주차    워터파크
# 8    하남 스타필드        워터파크    워터파크
# 9    하남 스타필드  경기도 호텔 수영장    워터파크
# 10   하남 스타필드       아쿠아필드    워터파크
# 11   하남 스타필드        메가박스      영화
# 12   하남 스타필드         찜질방     찜질방
# 13   하남 스타필드      스포츠몬스터  스포츠몬스터
# 14   하남 스타필드        키즈까페    키즈카페
# 15   하남 스타필드      신세계백화점     백화점
# 16   하남 스타필드    아쿠아필드 가격    워터파크
# 17   하남 스타필드    아쿠아필드 수건    워터파크
# 18   하남 스타필드          주차      주차
# 19   하남 스타필드          맛집    레스토랑
# 20   하남 스타필드       아쿠아필드    워터파크
# 21   하남 스타필드         신세계     백화점
# 22   하남 스타필드         찜질방     찜질방
# 23   하남 스타필드          카페     식음료
# 24   하남 스타필드        메가박스      영화
# 25   하남 스타필드          네일      네일
# 26   하남 스타필드      베이비엔젤스  베이비엔젤스
# 27   하남 스타필드         가는길     가는길
# 28   하남 스타필드      스포츠몬스터  스포츠몬스터
# 29   하남 스타필드          스파      스파
# 30   하남 스타필드        찜질스파      스파
# 31   하남 스타필드         미용실      뷰티
# 32   하남 스타필드         1주년     1주년
# 33   하남 스타필드          한샘      한샘
# 34   하남 스타필드        스타벅스     식음료
# 35   하남 스타필드        준오헤어      패션
# 36   하남 스타필드         나들이     나들이
# 37   하남 스타필드         데이트     데이트
# 38   하남 스타필드         발레복      패션
# 39   하남 스타필드         팥고당     식음료
# 40   하남 스타필드          근처      근처
# 41   하남 스타필드      신세계백화점     백화점
# 42   하남 스타필드        근처맛집     식음료
# 43   하남 스타필드          쇼핑      쇼핑
# 44   하남 스타필드          꽃집      꽃집
# 45   하남 스타필드          구경      구경
# 46   하남 스타필드        토이킹덤    토이킹덤
# 47  코엑스 스타필드         놀거리     놀거리
# 48  코엑스 스타필드          맛집     식음료
# 49  코엑스 스타필드       아쿠아리움   아쿠아리움

# %%
df3 = df[2]
df3.head()
# Out:
# 0    워터파크
# 1    워터파크
# 2    워터파크
# 3     식음료
# 4    워터파크
# Name: 2, dtype: object

# %%
shoppingmall = ["하남 스타필드", "코엑스 스타필드", "강변 테크노마트", "아이파크몰", "가든파이브", "타임스퀘어", "디큐브시티", "롯데몰 김포",
                 "롯데몰 은평", "ifc몰"]
i = 1
result = []
for i in range(len(shoppingmall)):
    i = i +1
    word = df3.loc[df[0] == i]
print(result)
# Out:
# []

# %%
hanam = df3.loc[df[0] == '하남 스타필드']

# %%
coex = df3.loc[df[0] == '코엑스 스타필드']

# %%
techno = df3.loc[df[0] == '강변 테크노마트']

# %%
ipark = df3.loc[df[0] == '아이파크몰']

# %%
gardenfive = df3.loc[df[0] == '가든파이브']

# %%
timessquare = df3.loc[df[0] == '타임스퀘어']

# %%
dcube = df3.loc[df[0] == '디큐브시티']

# %%
gimpo = df3.loc[df[0] == '롯데몰 김포']

# %%
eunpyeong = df3.loc[df[0] == '롯데몰 은평']

# %%
ifc = df3.loc[df[0] == 'ifc몰']

# %%
# df3.loc[:50]

# %%
# !pip install -q 'wordcloud[all]'
# Out:
#   wordcloud 1.5.0 does not provide the extra 'all'

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

def displayWordCloud(data = None, backgroundcolor = 'white', width=800, height=600 ):
    wordcloud = WordCloud(
                        font_path = fontpath,
                        stopwords = STOPWORDS, # 한국어는 해당이 없습니다. 한국어를 적용해 주려면 별도 처리가 필요합니다.
                        background_color = backgroundcolor, 
                         width = width, height = height).generate(data)
    plt.figure(figsize = (15 , 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
# Out:
# apt: invalid flag: -qq
# Usage: apt <apt and javac options> <source files>
# where apt options include:
#   -classpath <path>          Specify where to find user class files and annotation processor factories
#   -cp <path>                 Specify where to find user class files and annotation processor factories
#   -d <path>                  Specify where to place processor and javac generated class files
#   -s <path>                  Specify where to place processor generated source files
#   -source <release>          Provide source compatibility with specified release
#   -version                   Version information
#   -help                      Print a synopsis of standard options; use javac -help for more options
#   -X                         Print a synopsis of nonstandard options
#   -J<flag>                   Pass <flag> directly to the runtime system
#   -A[key[=value]]            Options to pass to annotation processors
#   -nocompile                 Do not compile source files to class files
#   -print                     Print out textual representation of specified types
#   -factorypath <path>        Specify where to find annotation processor factories
#   -factory <class>           Name of AnnotationProcessorFactory to use; bypasses default discovery process
# See javac -help for information on javac options.

# %%
displayWordCloud(' '.join(df3))

# %%
displayWordCloud(' '.join(hanam))

# %%
displayWordCloud(' '.join(coex))

# %%
displayWordCloud(' '.join(techno))

# %%
displayWordCloud(' '.join(ipark))

# %%
displayWordCloud(' '.join(gardenfive))

# %%
displayWordCloud(' '.join(timessquare))

# %%
displayWordCloud(' '.join(dcube))

# %%
displayWordCloud(' '.join(gimpo))

# %%
displayWordCloud(' '.join(eunpyeong))

# %%
displayWordCloud(' '.join(ifc))
